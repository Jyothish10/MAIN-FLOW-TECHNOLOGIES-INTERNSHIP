# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyothish10/MAIN-FLOW-TECHNOLOGIES-INTERNSHIP/blob/main/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fetching the Web Page

# %%
import requests

url = 'https://www.fcbarcelona.com/en/'
response = requests.get(url)

if response.status_code == 200:
    html = response.text
    # Proceed to parsing the HTML
else:
    print(f'Failed to retrieve page: {response.status_code}')

# %% [markdown]
# # Parsing HTML with BeautifulSoup

# %%
from bs4 import BeautifulSoup

# Parse the HTML content
soup = BeautifulSoup(html, 'html.parser')

# Example: Extracting all <p> tags
paragraphs = soup.find_all('p')

for p in paragraphs:
    print(p.text)
# Out:
# First Team
# Club
# Tickets & Museum
# Download the official FC Barcelona App
#  Get your favourite jersey and customize it
#  Take a piece of history home. The most exclusive products.
#  The star signing of the spring-summer season. Get ready for the festival season, good music and good weather.
#  Discover the best-selling items for the little ones at home
#
# Lewandowski
# 9
# Robert
# Lewandowski
#
#
# López
# 16
# Fermín
# López
#
#
# Raphinha
# 11
# Raphinha
#
#
# Jong
# 21
# Frenkie
# de Jong
#
#
# Gündogan
# 22
# Ilkay
# Gündogan
#
#
# Roque
# 19
# Vitor Roque
#
#
# Cancelo
# 2
# João Cancelo
#
#
# Félix
# 14
# João Félix
#
#
# Torres
# 7
# Ferran
# Torres
#
#
# Araujo
# 4
# Ronald
# Araujo

# %% [markdown]
# #Extracting Relevant Information

# %%
#Extracting all links (<a> tags)
links = soup.find_all('a', href=True)

for link in links:
    print(link['href'])
# Out:
# /en/
# https://one.fcbarcelona.com/en?int=WB_23-24_A129-90&btm_source=WebBarca&btm_medium=MainMenu&btm_campaign=BarcaOneLaunch_EN_DIG_OTT_WW
# https://store.fcbarcelona.com/en/?ext=OCM_420&utm_source=WebBarca&utm_medium=Menu&utm_campaign=MenuWebBarca_ORG_BLM_HOME_OCM_webBarca_TXT_WW_EN
# /en/tickets/things-to-do-in-barcelona
# https://www.fcbarcelona.com/en/culers/draws/draw-trip-new-york-barca-madrid-tickets?int=WB_24-25_A21-10&btm_source=WebBarca&btm_medium=NativeRibbon&btm_campaign=PR-NEWYORK_EN_DIG_DIG_WW
# https://www.fcbarcelona.com/en/
# https://www.fcbarcelona.cat/ca/
# https://www.fcbarcelona.es/es/
# https://www.fcbarcelona.fr/fr/
# https://www.fcbarcelona.jp/ja/
# http://www.fcbarcelona.cn/
# https://barcaacademy.fcbarcelona.com/en/?btm_source=WebBarca&btm_medium=BarcaSites&btm_campaign=BarcaAcademy_ORG_DIG_WEB_WebBarca_TXT_WW_EN
# ...

# %% [markdown]
# #Storing the Extracted Data

# %%
#Storing extracted data in a list
data_to_store = []
for p in paragraphs:
    data_to_store.append(p.text)

#Writing to a CSV file
import csv

with open('data.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    for item in data_to_store:
        writer.writerow([item])

# %%
with open('data.csv', 'r', encoding='utf-8') as f:
    for line in f:
        print(line)
# Out:
# First Team
#
# Club
#
# Tickets & Museum
#
# Download the official FC Barcelona App
#
#  Get your favourite jersey and customize it
#
#  Take a piece of history home. The most exclusive products.
#
# " The star signing of the spring-summer season. Get ready for the festival season, good music and good weather. "
#
#  Discover the best-selling items for the little ones at home
#
# "
#
# Lewandowski
#
# 9
#
# Robert
#
# Lewandowski
#
# "
#
# "
#
# López
#
# 16
#
# Fermín
#
# López
#
# "
#
# "
#
# Raphinha
#
# 11
#
# Raphinha
#
# "
#
# "
#
# Jong
#
# 21
#
# Frenkie
#
# de Jong
#
# "
#
# "
#
# Gündogan
#
# 22
#
# Ilkay
#
# Gündogan
#
# "
#
# "
#
# Roque
#
# 19
#
# Vitor Roque
#
# "
#
# "
#
# Cancelo
#
# 2
#
# João Cancelo
#
# "
#
# "
#
# Félix
#
# 14
#
# João Félix
#
# "
#
# "
#
# Torres
#
# 7
#
# Ferran
#
# Torres
#
# "
#
# "
#
# Araujo
#
# 4
#
# Ronald
#
# Araujo
#
# "
